# %% [markdown]
# <a href="https://colab.research.google.com/github/Daize-Samia/NLP_Preprocessing/blob/main/TP1NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Importation des bibliothèques nécessaires
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import spacy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt# Installation du package Kaggle sur l'environnement Colab
# !pip install kaggle

# Création du répertoire caché .kaggle dans le répertoire utilisateur
# !mkdir -p ~/.kaggle

# Importation de la fonctionnalité permettant de télécharger des fichiers dans Colab
from google.colab import files

# Téléchargement du fichier kaggle.json depuis l'ordinateur vers Colab
uploaded = files.upload()

# Déplacement du fichier téléchargé dans le répertoire .kaggle
# !mv kaggle.json ~/.kaggle/

# Attribution des bonnes permissions au fichier kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# Importation des bibliothèques nécessaires
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import spacy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ...
#      <input type="file" id="files-cbfaae68-5867-4ee2-83d0-9835369dcf8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbfaae68-5867-4ee2-83d0-9835369dcf8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Téléchargement d'un ensemble de données appelé "customer-support-on-twitter" depuis Kaggle
# !kaggle datasets download -d thoughtvector/customer-support-on-twitter
# Out:
# ...
#  94% 159M/169M [00:01<00:00, 159MB/s]
# 100% 169M/169M [00:01<00:00, 128MB/s]

# %%
# Décompression du fichier ZIP dans le répertoire /content

# !unzip /content/customer-support-on-twitter.zip
# Out:
# Archive:  /content/customer-support-on-twitter.zip
# replace sample.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Charger les données dans un DataFrame
df=pd.read_csv('/sample.csv')
df
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
#imprimer des informations spécifiques stockées dans une colonne appelée 'text' d'un DataFrame 'df'
print(df['text'])
print(df['text'][0])
print(df['text'][1])
# Out:
# 0     @AppleSupport causing the reply to be disregar...
# 1     @105835 Your business means a lot to us. Pleas...
# 2     @76328 I really hope you all change but I'm su...
# 3     @105836 LiveChat is online at the moment - htt...
# 4     @VirginTrains see attached error message. I've...
#                             ...
# 88    @105860 I wish Amazon had an option of where I...
# 89    They reschedule my shit for tomorrow https://t...
# 90    @105861 Hey Sara, sorry to hear of the issues ...
# 91    @Tesco bit of both - finding the layout cumber...
# 92    @105861 If that doesn't help please DM your fu...
# Name: text, Length: 93, dtype: object
# @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r

# %%
# ajout une nouvelle colonne nommée "text_lower" à un DataFrame existant nommé 'df' en utilisant la méthode 'str.lower()' de pandas
df["text_lower"] = df["text"].str.lower()
df.head()

# %%
import string

# Votre code pour charger ou créer le DataFrame 'df' ici

PUNCT_TO_REMOVE = string.punctuation

def remove_punctuation(text):
    """Fonction pour supprimer la ponctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

# Vérifiez si 'text_lower' existe dans votre DataFrame 'df'
if 'text_lower' in df.columns:
    df["text_no_punct"] = df["text_lower"].apply(lambda text: remove_punctuation(text))
    df.head()
else:
    print("La colonne 'text_lower' n'existe pas dans votre DataFrame.")
# Out:
# La colonne 'text_lower' n'existe pas dans votre DataFrame.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Création ou chargement du DataFrame 'df' avec la colonne 'text_no_punct' préalablement créée
# ...

STOPWORDS = set(stopwords.words('english'))

def remove_stopwords(text):
    """Fonction pour supprimer les mots vides"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# Assurez
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_emojis(text):
    #  # Définir un motif d'expression régulière pour faire correspondre les emojis
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U0001F004-\U0001F0CF"  # Miscellaneous Symbols and Pictographs
                           u"\U0001F170-\U0001F251"  # Enclosed Alphanumeric Supplement
                           "]+", flags=re.UNICODE)

    # Remove emojis using the regex pattern
    return emoji_pattern.sub(r'', text)
if 'text_no_stop_word' in df.columns:
  df["text_no_emojis"] = df["text_no_stop_word"].apply(lambda text: remove_emojis(text))
df.head()
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @AppleSupport causing the reply to be disregar...            119236
# 1  @105835 Your business means a lot to us. Pleas...               NaN
# 2  @76328 I really hope you all change but I'm su...            119238
# 3  @105836 LiveChat is online at the moment - htt...            119241
# 4  @VirginTrains see attached error message. I've...            119243
#
#    in_response_to_tweet_id
# 0                      NaN
# 1                 119239.0
# 2                      NaN
# ...

# %%
#remove urls:

def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)
if 'text_no_emojis' in df.columns:
    df["text_no_urls"] = df["text_no_emojis"].apply(lambda text: remove_urls(text))
    df.head()
else:
    print("La colonne 'text_no_emojis' n'existe pas dans votre DataFrame.")
# Out:
# La colonne 'text_no_emojis' n'existe pas dans votre DataFrame.

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

# Replace this DataFrame creation with your actual DataFrame initialization
data = {
    'text': ['Sample text 1 with no urls', 'Another text without urls', 'More text here']
}
df = pd.DataFrame(data)

nltk.download('punkt')

def tokenize_text(text):
    return word_tokenize(text)

# Apply tokenization to the 'text' column and create a new column 'text_tokenization'
df["text_tokenization"] = df["text"].apply(lambda text: tokenize_text(text))
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                          text                  text_tokenization
# 0  Sample text 1 with no urls  [Sample, text, 1, with, no, urls]
# 1   Another text without urls     [Another, text, without, urls]
# 2              More text here                 [More, text, here]

# %%
print(df["text_tokenesation"][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_tokenesation'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#lemmatisation  consiste à réduire les mots à leur forme de base, appelée "lemme". Le lemme est la forme canonique ou le dictionnaire d'un mot.
import spacy

nlp = spacy.load("en_core_web_sm")

def lemmatize_words(text):
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc])
if 'text_no_urls' in df.columns:
  df["text_lemmatized"] = df["text_no_urls"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
#                          text                  text_tokenization
# 0  Sample text 1 with no urls  [Sample, text, 1, with, no, urls]
# 1   Another text without urls     [Another, text, without, urls]
# 2              More text here                 [More, text, here]

# %%
print(df["text_lemmatized"][0])

# %%
# Initialiser le stemmer (Porter Stemmer)  pour réduire les mots à leur racine ou base commune, souvent en supprimant des affixes comme les préfixes ou les suffixes.
stemmer = PorterStemmer()

# Fonction pour effectuer le stemming
def stem_text(text):
    tokens = nltk.word_tokenize(text)  # Tokenisation avec NLTK
    stemmed_tokens = [stemmer.stem(token) for token in tokens]  # Stemming
    return " ".join(stemmed_tokens)

# Ajouter la colonne 'text-stemmed' au DataFrame et y appliquer le stemming
if 'text_no_urls' in df.columns:
  df["text_stemmed"] = df["text_no_urls"].apply(lambda text: stem_text(text))
# Initialiser le stemmer (Porter Stemmer)
  print(df["text_stemmed"][0])
